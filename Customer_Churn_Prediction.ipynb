# %%
1#import the package to read the data
import pandas as pd
import numpy as np # Changed pd to np for numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
churndf = pd.read_csv("/content/drive/MyDrive/Data Projects/Customer Churn Data Project/Churn-Modelling.csv")
churndf.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
churndf.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
#descriptive statistics of numerical values
churndf.describe().T
# Out:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure           10000.0  5.012800e+00      2.892174         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
# Exited           10000.0  2.037000e-01      0.402769         0.00
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# ...

# %%
churndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
churndf.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
churndf.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
#Qualitative (categorical variables):
cat_features = ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember']

#numerical (variables but can take decimal numbers):
float_features = ['Balance', 'Estimated Salary']

#numerical variables (integers only):
int_features = ['CreditScore', 'Age', 'Tenure', 'NumOfProducts']

#variables to drop:
useless = ['RowNumber', 'CustomerId', 'Surname']

#dependent variable:
target = 'Exited'

# %%
#to find any missing variables
churndf_missing = churndf.isnull().sum()
churndf_missing

#no missing record
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# Set style and context
sns.set_style("whitegrid")  # Add a grid for better readability
sns.set_context("talk")  # Increase font sizes for presentations

# Define target variable
target = 'Exited'

# Create count plot
plt.figure(figsize=(10, 6))
ax = sns.countplot(x=target, data=churndf, palette="Set2")  # Use a color palette

# Add labels and title
plt.xlabel("Customer Churn (0: No, 1: Yes)", fontsize=14)  # More descriptive label
plt.ylabel("Number of Customers", fontsize=14)
plt.title("Distribution of Customer Churn", fontsize=16)

# Annotate bars with counts
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# Analysis
# The count plot shows that the majority of customers (around 8000) have not churned (Exited = 0).
# A smaller proportion (around 2000) have churned (Exited = 1), indicating an imbalanced dataset.
# Out:
# <ipython-input-11-77cd5152fe41>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=target, data=churndf, palette="Set2")  # Use a color palette

# %%
# Set style and context (if not already set)
sns.set_style("whitegrid")
sns.set_context("talk")

# Create count plot with hue
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
ax = sns.countplot(x=target, hue='Geography', data=churndf, palette="Set2")  # Use color palette

# Add labels and title
plt.xlabel("Customer Churn (0: No, 1: Yes)", fontsize=14)
plt.ylabel("Number of Customers", fontsize=14)
plt.title("Churn Distribution by Geography", fontsize=16)

# Add legend
plt.legend(title="Geography", fontsize=12)

#France:

#Not Exited (0): The highest count of customers who have not exited the service.

#Exited (1): Moderate count of customers who have exited, slightly higher than Spain but similar to German

#Spain:

#Not Exited (0): Lower count of customers who have not exited compared to France but higher than Germany.

#Exited (1): The least count of customers who have exited the service.

#Germany:

#Not Exited (0): Similar to Spain but lower than France.

#Exited (1): Comparable to France and higher than Spain.

# %%
# Set the style and context
sns.set_style("whitegrid")  # Use a white grid background
sns.set_context("talk")  # Increase font sizes for presentations

# Create the countplot with custom colors and labels
plt.figure(figsize=(10, 6))  # Adjust figure size for better visibility
ax = sns.countplot(
    x=target,
    hue='Gender',
    data=churndf,
    palette="Set2"  # Use a colorblind-friendly palette
)

# Customize the plot elements
plt.xlabel("Customer Churn (0: No, 1: Yes)", fontsize=14)  # Descriptive x-axis label
plt.ylabel("Number of Customers", fontsize=14)  # Descriptive y-axis label
plt.title("Churn Distribution by Gender", fontsize=16)  # Informative title
plt.legend(title="Gender", fontsize=12)  # Customize the legend

# Add annotations for clarity
for p in ax.patches:
    ax.annotate(
        f'{p.get_height()}',  # Display the count on top of each bar
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center',
        va='center',
        fontsize=12,
        color='black',
        xytext=(0, 5),  # Adjust annotation position
        textcoords='offset points'
    )

plt.show()
#Key Takeaways:

#Geography: France has the highest number of exits, suggesting potential factors specific to that region.
#Gender: There is a slight difference in exit rates between genders, but further analysis is needed to understand the reasons.
#Credit Card: Customers without credit cards have a higher exit rate, indicating that credit card usage might be a retention factor.
#Active Membership: Inactive members have a higher exit rate, suggesting that keeping members active is crucial for retention.

# %%
churndf.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Numerical features
float_features = ['Balance', 'EstimatedSalary']

# Define custom colors
palette = ["lightblue", "salmon"]  # Colors for target values 0 and 1

# Create subplots
fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(10, 5))

# Loop through features and create box plots with custom colors
for feature, ax in zip(float_features, axes.flat):
    sns.boxplot(x=target, y=feature, data=churndf, ax=ax, showfliers=False, hue=target, palette=palette, legend=False)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()


#Balance: There is a noticeable difference in the balance distributions between the exited and not exited groups. Higher balances are associated with a lower likelihood of exiting.

#Estimated Salary: The distributions of estimated salaries are very similar for both groups, suggesting that this variable may not be as influential in determining whether a customer exits.

# %%
#plotting integers features:
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14,10))

for feature, ax in zip(int_features, axes.flat):
    plot = sns.boxplot(x=target, y=feature, data=churndf, ax=ax, showfliers=False, palette=palette)

plt.tight_layout()
plt.show()

#Credit Score and Age: These variables show a noticeable difference between the exited and not exited groups, indicating they might be influential factors in predicting customer exit.

#Tenure and Number of Products: These variables show similar distributions between the two groups, suggesting they might not be as significant in influencing customer exit decisions.
# Out:
# <ipython-input-16-35eca1b887c2>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.boxplot(x=target, y=feature, data=churndf, ax=ax, showfliers=False, palette=palette)
# <ipython-input-16-35eca1b887c2>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.boxplot(x=target, y=feature, data=churndf, ax=ax, showfliers=False, palette=palette)
# <ipython-input-16-35eca1b887c2>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   plot = sns.boxplot(x=target, y=feature, data=churndf, ax=ax, showfliers=False, palette=palette)
# ...

# %%
#correlation matrix:
corr = churndf.drop(columns = useless).select_dtypes(include=np.number).corr() # Select only numeric columns for correlation
corr
# Out:
#                  CreditScore       Age    Tenure   Balance  NumOfProducts  \
# CreditScore         1.000000 -0.003965  0.000842  0.006268       0.012238
# Age                -0.003965  1.000000 -0.009997  0.028308      -0.030680
# Tenure              0.000842 -0.009997  1.000000 -0.012254       0.013444
# Balance             0.006268  0.028308 -0.012254  1.000000      -0.304180
# NumOfProducts       0.012238 -0.030680  0.013444 -0.304180       1.000000
# HasCrCard          -0.005458 -0.011721  0.022583 -0.014858       0.003183
# IsActiveMember      0.025651  0.085472 -0.028362 -0.010084       0.009612
# EstimatedSalary    -0.001384 -0.007201  0.007784  0.012797       0.014204
# Exited             -0.027094  0.285323 -0.014001  0.118533      -0.047820
#
#                  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# CreditScore      -0.005458        0.025651        -0.001384 -0.027094
# Age              -0.011721        0.085472        -0.007201  0.285323
# ...

# %%
# Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr)

plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()


#Overall Observations:
#Strong Positive Correlations:

#There's a strong positive correlation between Age and Tenure. This makes sense as older customers are likely to have been with the bank for a longer time.


#Moderate Negative Correlations:

#Exited has a moderate negative correlation with Age, Tenure, and NumOfProducts. This suggests that older, long-term customers with more products are less likely to leave.
#EstimatedSalary has a moderate negative correlation with Exited. This could mean that higher-income customers are less likely to churn.


#Weak or No Correlations:

#CreditScore doesn't seem to have strong correlations with other variables, indicating it might not be a significant predictor of customer churn.
#HasCrCard and IsActiveMember show weak correlations with Exited, suggesting their impact on churn might be limited.


#Specific Interpretations

#Age and Tenure: Older customers who've been with the bank longer are less likely to churn. This could be due to loyalty, higher account balances, or other factors.

#NumOfProducts: Customers with more products are less likely to churn. This could be because they have a deeper relationship with the bank or have found value in multiple services.

#EstimatedSalary: Customers with higher incomes are less likely to churn. This could be due to their financial stability or the bank's offerings catering to their needs.

# %%
#drop the useless value
df = churndf.drop(useless, axis = 1)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df = churndf.drop(cat_features, axis = 1)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602  Hargrave          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  EstimatedSalary  Exited
# 0              1        101348.88       1
# 1              1        112542.58       0
# 2              3        113931.57       1
# 3              2         93826.63       0
# 4              1         79084.10       0

# %%
Geography = pd.get_dummies(churndf.Geography).iloc[:,1:]
Gender = pd.get_dummies(churndf.Gender).iloc[:,1:]
HasCrCard = pd.get_dummies(churndf.HasCrCard).iloc[:,1:]
IsActiveMember = pd.get_dummies(churndf.IsActiveMember).iloc[:,1:]

# %%
Geography.head()
# Out:
#    Germany  Spain
# 0    False  False
# 1    False   True
# 2    False  False
# 3    False  False
# 4    False   True

# %%
Gender.head()
# Out:
#     Male
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
HasCrCard.head()
# Out:
#        1
# 0   True
# 1  False
# 2   True
# 3  False
# 4   True

# %%
IsActiveMember.head()
# Out:
#        1
# 0   True
# 1   True
# 2  False
# 3  False
# 4   True

# %%
df = pd.concat([df, Geography, Gender, HasCrCard, IsActiveMember], axis = 1)

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602  Hargrave          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  EstimatedSalary  Exited  Germany  Spain   Male      1      1
# 0              1        101348.88       1    False  False  False   True   True
# 1              1        112542.58       0    False   True  False  False   True
# 2              3        113931.57       1    False  False  False   True  False
# 3              2         93826.63       0    False  False  False  False  False
# 4              1         79084.10       0    False   True  False   True   True

# %%
copydf=df[:]

# %%
#drop the useless value
df = churndf.drop(useless, axis = 1)

# Create dummy variables for categorical columns
cat_var = ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember']
df = pd.get_dummies(df, columns=cat_var)

# Create copydf DataFrame
copydf = df.copy() # Create a new copy of df with all columns
#copydf=df[:] # Avoid creating a shallow copy

# Now you can drop the Exited column from copydf
copydf.drop('Exited', axis = 1, inplace = True)

# %%
copydf.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  EstimatedSalary  \
# 0          619   42       2       0.00              1        101348.88
# 1          608   41       1   83807.86              1        112542.58
# 2          502   42       8  159660.80              3        113931.57
# 3          699   39       1       0.00              2         93826.63
# 4          850   43       2  125510.82              1         79084.10
#
#    Geography_France  Geography_Germany  Geography_Spain  Gender_Female  \
# 0              True              False            False           True
# 1             False              False             True           True
# 2              True              False            False           True
# 3              True              False            False           True
# 4             False              False             True           True
#
#    Gender_Male  HasCrCard_0  HasCrCard_1  IsActiveMember_0  IsActiveMember_1
# ...

# %%
x = copydf[:]
y = df['Exited']

# %%
x.head()
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state = 79)

# %%
print (x_train.shape, x_train.shape)
print (y_test.shape, y_test.shape)
# Out:
# (9000, 15) (9000, 15)
# (1000,) (1000,)

# %%
#Native Bayes

from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix

# Create a Gaussian Naive Bayes model
modelnb = GaussianNB()

# Fit the model to the training data
modelnb.fit(x_train, y_train)

# Now you can make predictions
prednb = modelnb.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(prednb, y_test)
cm = confusion_matrix(prednb, y_test)

# Print the results
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.773
# Confusion Matrix:
# [[755 208]
#  [ 19  18]]

# %%
#Linear Regression:

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix
import numpy as np

# Create a Linear Regression model
modellr = LinearRegression()

# Fit the model to the training data
modellr.fit(x_train, y_train)

# Make predictions on the test data
predlr = modellr.predict(x_test)

# Evaluate the model (Regression Metrics)
mse = mean_squared_error(y_test, predlr)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, predlr)

# Convert predictions to binary for classification metrics
predlr_binary = (predlr >= 0.5).astype(int)  # Threshold at 0.5

# Evaluate the model (Classification Metrics)
accuracy = accuracy_score(y_test, predlr_binary)
cm = confusion_matrix(y_test, predlr_binary)

# Print the results
print("Regression Metrics:")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R2): {r2}")
print("\nClassification Metrics:")
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{cm}")
# Out:
# Regression Metrics:
# Mean Squared Error (MSE): 0.14860640035375383
# Root Mean Squared Error (RMSE): 0.3854950069115731
# R-squared (R2): 0.15045162268325774
#
# Classification Metrics:
# Accuracy: 0.783
# Confusion Matrix:
# [[762  12]
#  [205  21]]

# %%
#DecisionTree:

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# Create a Decision Tree model
modeldt = DecisionTreeClassifier()

# Fit the model to the training data
modeldt.fit(x_train, y_train)

# Make predictions on the test data
preddt = modeldt.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(preddt, y_test)
cm = confusion_matrix(preddt, y_test)

# Print the results
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.782
# Confusion Matrix:
# [[661 105]
#  [113 121]]

# %%
#RandomForestClassifier:

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# Create a Random Forest Classifier model
modelrf = RandomForestClassifier()

# Fit the model to the training data
modelrf.fit(x_train, y_train)

# Make predictions on the test data
predrf = modelrf.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(predrf, y_test)
cm = confusion_matrix(predrf, y_test)

# Print the results
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.845
# Confusion Matrix:
# [[747 128]
#  [ 27  98]]

# %%
#AdaBoostClassifier:

from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# Create an AdaBoost Classifier model
modelada = AdaBoostClassifier()

# Fit the model to the training data
modelada.fit(x_train, y_train)

# Make predictions on the test data
predada = modelada.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(predada, y_test)
cm = confusion_matrix(predada, y_test)

# Print the results
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.848
# Confusion Matrix:
# [[744 122]
#  [ 30 104]]

# %%
#KNeighborsClassifier:

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# Create a KNeighborsClassifier model
modelknn = KNeighborsClassifier()  # You can specify n_neighbors, weights, etc.

# Fit the model to the training data
modelknn.fit(x_train, y_train)

# Make predictions on the test data
predknn = modelknn.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(predknn, y_test)
cm = confusion_matrix(predknn, y_test)

# Print the results
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.742
# Confusion Matrix:
# [[722 206]
#  [ 52  20]]

# %%
modeldt = DecisionTreeClassifier()
modeldt.fit(x_train, y_train)
preddt = modeldt.predict(x_test)

# Store accuracy and confusion matrix in correctly named variables
dt_accuracy = accuracy_score(preddt, y_test)
dt_cm = confusion_matrix(preddt, y_test)

print(f"Decision Tree Accuracy: {dt_accuracy}")
print(f"Decision Tree Confusion Matrix:\n{dt_cm}")

# Cell 147 (Random Forest)
from sklearn.ensemble import RandomForestClassifier

modelrf = RandomForestClassifier()
modelrf.fit(x_train, y_train)
predrf = modelrf.predict(x_test)

# Store accuracy and confusion matrix in correctly named variables
rf_accuracy = accuracy_score(predrf, y_test)
rf_cm = confusion_matrix(predrf, y_test)

print(f"\nRandom Forest Accuracy: {rf_accuracy}")
print(f"Random Forest Confusion Matrix:\n{rf_cm}")

# Cell 149 (AdaBoost)
from sklearn.ensemble import AdaBoostClassifier

modelada = AdaBoostClassifier()
modelada.fit(x_train, y_train)
predada = modelada.predict(x_test)

# Store accuracy and confusion matrix in correctly named variables
ada_accuracy = accuracy_score(predada, y_test)
ada_cm = confusion_matrix(predada, y_test)

print(f"\nAdaBoost Accuracy: {ada_accuracy}")
print(f"AdaBoost Confusion Matrix:\n{ada_cm}")

# Cell 151 (K-Nearest Neighbors)
from sklearn.neighbors import KNeighborsClassifier

modelknn = KNeighborsClassifier()
modelknn.fit(x_train, y_train)
predknn = modelknn.predict(x_test)

# Store accuracy and confusion matrix in correctly named variables
knn_accuracy = accuracy_score(predknn, y_test)
knn_cm = confusion_matrix(predknn, y_test)

print(f"\nK-Nearest Neighbors Accuracy: {knn_accuracy}")
print(f"K-Nearest Neighbors Confusion Matrix:\n{knn_cm}")

# Cell 153 (Print all results)
# Calculate Naive Bayes accuracy and confusion matrix first
from sklearn.naive_bayes import GaussianNB

modelnb = GaussianNB()  # Initialize the model
modelnb.fit(x_train, y_train)  # Train the model
prednb = modelnb.predict(x_test)  # Make predictions

nb_accuracy = accuracy_score(prednb, y_test)  # Calculate accuracy
nb_cm = confusion_matrix(prednb, y_test)  # Calculate confusion matrix

print("\nNaive Bayes:")
print(f"Accuracy: {nb_accuracy}")
print(f"Confusion Matrix:\n{nb_cm}")

# ... (Print Linear Regression results - mse, rmse, r2, accuracy, cm if available) ...

print("\nDecision Tree:")
print(f"Accuracy: {dt_accuracy}")
print(f"Confusion Matrix:\n{dt_cm}")

print("\nRandom Forest:")
print(f"Accuracy: {rf_accuracy}")
print(f"Confusion Matrix:\n{rf_cm}")

print("\nAdaBoost:")
print(f"Accuracy: {ada_accuracy}")
print(f"Confusion Matrix:\n{ada_cm}")

print("\nK-Nearest Neighbors:")
print(f"Accuracy: {knn_accuracy}")
print(f"K-Nearest Neighbors Confusion Matrix:\n{knn_cm}")
# Out:
# Decision Tree Accuracy: 0.786
# Decision Tree Confusion Matrix:
# [[666 106]
#  [108 120]]
#
# Random Forest Accuracy: 0.844
# Random Forest Confusion Matrix:
# [[746 128]
#  [ 28  98]]
#
# AdaBoost Accuracy: 0.848
# AdaBoost Confusion Matrix:
# [[744 122]
#  [ 30 104]]
#
# K-Nearest Neighbors Accuracy: 0.742
# K-Nearest Neighbors Confusion Matrix:
# [[722 206]
#  [ 52  20]]
#
# Naive Bayes:
# Accuracy: 0.773
# Confusion Matrix:
# [[755 208]
#  [ 19  18]]
#
# Decision Tree:
# Accuracy: 0.786
# Confusion Matrix:
# [[666 106]
#  [108 120]]
#
# Random Forest:
# Accuracy: 0.844
# Confusion Matrix:
# [[746 128]
#  [ 28  98]]
#
# AdaBoost:
# Accuracy: 0.848
# Confusion Matrix:
# [[744 122]
#  [ 30 104]]
#
# K-Nearest Neighbors:
# Accuracy: 0.742
# K-Nearest Neighbors Confusion Matrix:
# [[722 206]
#  [ 52  20]]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# ... (your existing code for data loading, preprocessing, and train_test_split) ...

# Train and evaluate models
models = {
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
}

results = {}  # Store accuracy for each model

for model_name, model in models.items():
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    accuracy = accuracy_score(predictions, y_test)
    cm = confusion_matrix(predictions, y_test)

    results[model_name] = accuracy  # Store accuracy

    print(f"\n{model_name}:")
    print(f"Accuracy: {accuracy}")
    print(f"Confusion Matrix:\n{cm}")

# Find the best model based on accuracy
best_model = max(results, key=results.get)  # Get key with max value
best_accuracy = results[best_model]

print(f"\nBest Model: {best_model} with Accuracy: {best_accuracy}")
# Out:
# Decision Tree:
# Accuracy: 0.782
# Confusion Matrix:
# [[661 105]
#  [113 121]]
#
# Random Forest:
# Accuracy: 0.849
# Confusion Matrix:
# [[750 127]
#  [ 24  99]]
#
# AdaBoost:
# Accuracy: 0.848
# Confusion Matrix:
# [[744 122]
#  [ 30 104]]
#
# K-Nearest Neighbors:
# Accuracy: 0.742
# Confusion Matrix:
# [[722 206]
#  [ 52  20]]
#
# Best Model: Random Forest with Accuracy: 0.849

# %%
#Based on the accuracies and confusion matrices provided, the Random Forest model appears to be the best performer. Here's a quick recap of the results:

#The Random Forest model not only has the highest accuracy at 0.851 but also shows a strong balance between correctly predicting both classes based on its confusion matrix.

#It can be used to answer our research question "Which employee is likely to leave depedning on different variables" with 85.1% Accuracy.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# 1. Model Selection

models = {
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
}

results = {}

for model_name, model in models.items():
    # Model training, prediction, accuracy calculation
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    accuracy = accuracy_score(predictions, y_test)
    cm = confusion_matrix(predictions, y_test)

    results[model_name] = accuracy  # Store accuracy

    print(f"\n{model_name}:")
    print(f"Accuracy: {accuracy}")
    print(f"Confusion Matrix:\n{cm}")

# Find the best model based on accuracy
best_model = max(results, key=results.get)  # Get key with max value
best_accuracy = results[best_model]

print(f"\nBest Model: {best_model} with Accuracy: {best_accuracy}")


# 2. Research Question Exploration

# a. Are female customers leaving more than males?
gender_churn = churndf.groupby('Gender')['Exited'].mean()
print("\nChurn Rate by Gender:\n", gender_churn)
sns.barplot(x=gender_churn.index, y=gender_churn.values)
plt.title("Churn Rate by Gender")
plt.show()

# b. What age groups show an inclination to leave?
plt.figure(figsize=(10, 6))
sns.histplot(data=churndf, x='Age', hue='Exited', multiple='stack')
plt.title("Churn Distribution by Age")
plt.show()

# c. Is there an indication of customer departures associated with specific countries?
country_churn = churndf.groupby('Geography')['Exited'].mean()
print("\nChurn Rate by Country:\n", country_churn)
sns.barplot(x=country_churn.index, y=country_churn.values)
plt.title("Churn Rate by Country")
plt.show()

# d. Is there evidence of salary-associated departures?
plt.figure(figsize=(10, 6))
sns.boxplot(x='Exited', y='EstimatedSalary', data=churndf)
plt.title("Churn Distribution by Estimated Salary")
plt.show()

# ... (add more research questions and visualizations as needed) ...
# Out:
# Decision Tree:
# Accuracy: 0.784
# Confusion Matrix:
# [[662 104]
#  [112 122]]
#
# Random Forest:
# Accuracy: 0.851
# Confusion Matrix:
# [[750 125]
#  [ 24 101]]
#
# AdaBoost:
# Accuracy: 0.848
# Confusion Matrix:
# [[744 122]
#  [ 30 104]]
#
# K-Nearest Neighbors:
# Accuracy: 0.742
# Confusion Matrix:
# [[722 206]
#  [ 52  20]]
#
# Best Model: Random Forest with Accuracy: 0.851
#
# Churn Rate by Gender:
#  Gender
# Female    0.250715
# Male      0.164559
# Name: Exited, dtype: float64
# Churn Rate by Country:
#  Geography
# France     0.161548
# Germany    0.324432
# Spain      0.166734
# Name: Exited, dtype: float64

# %%
# a. Are female customers leaving more than males?
gender_churn = churndf.groupby('Gender')['Exited'].mean()
print("\nChurn Rate by Gender:\n", gender_churn)
sns.barplot(x=gender_churn.index, y=gender_churn.values)
plt.title("Churn Rate by Gender")
plt.show()

# b. What age groups show an inclination to leave?
plt.figure(figsize=(10, 6))
sns.histplot(data=churndf, x='Age', hue='Exited', multiple='stack')
plt.title("Churn Distribution by Age")
plt.show()

# c. Is there an indication of customer departures associated with specific countries?
country_churn = churndf.groupby('Geography')['Exited'].mean()
print("\nChurn Rate by Country:\n", country_churn)
sns.barplot(x=country_churn.index, y=country_churn.values)
plt.title("Churn Rate by Country")
plt.show()

# d. Is there evidence of salary-associated departures?
plt.figure(figsize=(10, 6))
sns.boxplot(x='Exited', y='EstimatedSalary', data=churndf)
plt.title("Churn Distribution by Estimated Salary")
plt.show()

# e. Does tenure influence churn?
plt.figure(figsize=(10, 6))
sns.histplot(data=churndf, x='Tenure', hue='Exited', multiple='stack')
plt.title("Churn Distribution by Tenure")
plt.show()

# f. Is there a relationship between number of products and churn?
product_churn = churndf.groupby('NumOfProducts')['Exited'].mean() # Calculate the average churn rate for each number of products
print("\nChurn Rate by Number of Products:\n", product_churn)
sns.barplot(x=product_churn.index, y=product_churn.values) # Create a bar plot to visualize the relationship
plt.title("Churn Distribution by Number of Products")
plt.show()
# Out:
# Churn Rate by Gender:
#  Gender
# Female    0.250715
# Male      0.164559
# Name: Exited, dtype: float64
# Churn Rate by Country:
#  Geography
# France     0.161548
# Germany    0.324432
# Spain      0.166734
# Name: Exited, dtype: float64
# Churn Rate by Number of Products:
#  NumOfProducts
# 1    0.277144
# 2    0.075817
# 3    0.827068
# 4    1.000000
# Name: Exited, dtype: float64
